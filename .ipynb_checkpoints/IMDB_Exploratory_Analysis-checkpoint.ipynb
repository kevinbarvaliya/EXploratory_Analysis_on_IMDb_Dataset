# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read CSV file into a Dataframe

# %%
movies = pd.read_csv("Imdb_clean.csv")

# %%
movies.tail()
# Out:
#                           Movie_name  \
# 995                          Sabrina
# 996            From Here to Eternity
# 997  Snow White and the Seven Dwarfs
# 998                     The 39 Steps
# 999                The Invisible Man
#
#                                         Genre  Year  Time  Rating   Votes  \
# 995        Comedy, Drama, Romance              1954   113     7.6   64057
# 996           Drama, Romance, War              1953   118     7.6   46523
# 997  Animation, Adventure, Family              1937    83     7.6  195286
# 998      Crime, Mystery, Thriller              1935    86     7.6   56302
# 999                Horror, Sci-Fi              1933    71     7.6   34397
#
#      Gross(Million_$)  Metascore          Director
# 995               NaN       72.0      Billy Wilder
# 996             30.50       85.0    Fred Zinnemann
# 997            184.93       95.0  William Cottrell
# 998               NaN       93.0  Alfred Hitchcock
# 999               NaN       87.0       James Whale

# %% [markdown]
# # Cheking Null values and Data types

# %%
#Currently, we are not removing rows that contain null values. We will remove these rows later.
movies.isnull().sum()
# Out:
# Movie_name            0
# Genre                 0
# Year                  0
# Time                  0
# Rating                0
# Votes                 0
# Gross(Million_$)    154
# Metascore           164
# Director              0
# dtype: int64

# %%
movies.dtypes
# Out:
# Movie_name           object
# Genre                object
# Year                  int64
# Time                  int64
# Rating              float64
# Votes                 int64
# Gross(Million_$)    float64
# Metascore           float64
# Director             object
# dtype: object

# %% [markdown]
# # Top Voted Movies

# %%
#sorting values by votes in decending orders, so we can see top voted movies at top.
top_voted = movies.sort_values(["Votes"], ascending=False)

# %%
top_voted.head()
# Out:
#                   Movie_name                                  Genre  Year  \
# 0   The Shawshank Redemption                      Drama              1994
# 2            The Dark Knight       Action, Crime, Drama              2008
# 11                 Inception  Action, Adventure, Sci-Fi              2010
# 13                Fight Club                      Drama              1999
# 15              Forrest Gump             Drama, Romance              1994
#
#     Time  Rating    Votes  Gross(Million_$)  Metascore           Director
# 0    142     9.3  2584194             28.34       81.0     Frank Darabont
# 2    152     9.0  2554477            534.86       84.0  Christopher Nolan
# 11   148     8.8  2267882            292.58       74.0  Christopher Nolan
# 13   139     8.8  2034222             37.03       66.0      David Fincher
# 15   142     8.8  1993775            330.25       82.0    Robert Zemeckis

# %%
#Top 10 Most Voted Movies from 1000 top rated movies.
plt.figure(figsize=(15,5))
sns.barplot(x = top_voted["Movie_name"][:10], y = top_voted["Votes"][:10]) 
plt.title("Top Voted Movies" ,weight = "bold", size = 20)
plt.xlabel('Movie Name', fontsize = 15 )
plt.ylabel("Votes (Millions)", fontsize = 15)
plt.xticks(rotation=90, fontsize = 12)
plt.yticks( fontsize = 12)
plt.show()

# %% [markdown]
# # Top Rated Movies

# %%
#Here we are sorting our data by  rating and votes
#If we sort data only with ratings, it might be possible that only some people rated a movie with a good rating.
top_rated = movies.sort_values(["Rating","Votes"], ascending=False)

# %%
top_rated.head()
# Out:
#                                       Movie_name  \
# 0                       The Shawshank Redemption
# 1                                  The Godfather
# 2                                The Dark Knight
# 3  The Lord of the Rings: The Return of the King
# 4                               Schindler's List
#
#                                    Genre  Year  Time  Rating    Votes  \
# 0                      Drama              1994   142     9.3  2584194
# 1               Crime, Drama              1972   175     9.2  1779649
# 2       Action, Crime, Drama              2008   152     9.0  2554477
# 3   Action, Adventure, Drama              2003   201     9.0  1776123
# 4  Biography, Drama, History              1993   195     9.0  1315374
#
#    Gross(Million_$)  Metascore              Director
# 0             28.34       81.0        Frank Darabont
# 1            134.97      100.0  Francis Ford Coppola
# 2            534.86       84.0     Christopher Nolan
# 3            377.85       94.0         Peter Jackson
# 4             96.90       94.0       Oskar Schindler

# %%
#Top 10 movies with Highest rating.
plt.figure(figsize=(15,5))
sns.barplot(x = top_rated["Movie_name"][:10], y = top_rated["Rating"][:10])
plt.title("Top Rated Movies", weight = "bold", size = 20)
plt.xlabel('Movie Name', fontsize = 15 )
plt.ylabel('Rating', fontsize = 15)
plt.xticks(rotation=90, fontsize = 12)
plt.yticks( fontsize = 12)
plt.show()

# %%
#Meta score of Top rated movies
plt.figure(figsize=(15,5))
sns.barplot(x = top_rated["Movie_name"][:5], y = top_rated["Metascore"][:5])
plt.title("Metascore of top Rated Movies", weight = "bold", size = 20)
plt.xlabel('Movie Name', fontsize = 15 )
plt.ylabel('Metascore', fontsize = 15)
plt.xticks(rotation=90, fontsize = 12)
plt.yticks( fontsize = 12)
plt.show()

# %% [markdown]
# # Movies with highest Gross

# %%
#Sorting data by Gross in descending order
highest_gross = movies.sort_values(["Gross(Million_$)"], ascending  = False)


plt.figure(figsize=(15,5))
sns.barplot(x = highest_gross["Movie_name"][:5], y = highest_gross["Gross(Million_$)"][:5])
plt.title("Movies with highest Gross", weight = "bold", size = 20)
plt.xlabel('Movie Name', fontsize = 15 )
plt.ylabel('Gross (Million_$)', fontsize = 15)
plt.xticks(rotation=90, fontsize = 12)
plt.yticks(fontsize = 12)

plt.show()

# %% [markdown]
# # Directors who has directed maximum movies

# %%
#Grouping data by Director to count how many movies directed by each Directore
director = movies.groupby("Director")["Movie_name"].count() 

#Sorting data  by  number of movies Directed in descend order
director.sort_values(ascending = False ,inplace = True)

#Converting retrieved series data into a data frame. We are resetting the index because we want directors name as a column, not as an index.
director = director.to_frame().reset_index()

#Renaming the columns
director = director.rename(columns={"Movie_name": "Number_of_Movies"})
director.head()
# Out:
#            Director  Number_of_Movies
# 0  Alfred Hitchcock                13
# 1    Akira Kurosawa                12
# 2  Steven Spielberg                10
# 3    Hayao Miyazaki                10
# 4      Billy Wilder                 9

# %%
plt.figure(figsize = (20,8))
sns.barplot(x = director["Director"][:20], y = director["Number_of_Movies"][:20])
plt.title("Frequency of Director in Top 1000 movies", weight = "bold", size = 20)
plt.xlabel('Director Name', fontsize = 15 )
plt.ylabel('Number of times', fontsize = 15)
plt.xticks(rotation=90, fontsize = 15)
plt.yticks(fontsize = 15)

plt.show()

# %% [markdown]
# # Droping NA

# %%
#We are removing rows which contain NA rows 
clean_movies = movies.dropna()

# %%
clean_movies.isna().sum()
# Out:
# Movie_name          0
# Genre               0
# Year                0
# Time                0
# Rating              0
# Votes               0
# Gross(Million_$)    0
# Metascore           0
# Director            0
# dtype: int64

# %% [markdown]
# # Highest Rated Genre

# %%
#Creating separate dataframe to calculate the highest rated genre
genre_rating = clean_movies[["Genre","Rating"]]
genre_rating.head()
# Out:
#                                    Genre  Rating
# 0                      Drama                 9.3
# 1               Crime, Drama                 9.2
# 2       Action, Crime, Drama                 9.0
# 3   Action, Adventure, Drama                 9.0
# 4  Biography, Drama, History                 9.0

# %%
#setting Rating as index  
genre_rating.set_index("Rating" , inplace = True)

# %%
#spliting  genre by ", " to separate each genre.
genre = genre_rating['Genre'].str.split(',')

#exploding lists to convert each list element to series 
genre_rating_exp = genre.explode()

# %%
#removing leading and the trailing spaces of each genre.
genre_rating_exp = genre_rating_exp.str.strip()
genre_rating_exp
# Out:
# Rating
# 9.3        Drama
# 9.2        Crime
# 9.2        Drama
# 9.0       Action
# 9.0        Crime
#          ...
# 7.6      Romance
# 7.6          War
# 7.6    Animation
# 7.6    Adventure
# 7.6       Family
# Name: Genre, Length: 1917, dtype: object

# %%
#converting exploded series into dataFrame. Sorting data frame by index(Genre)
genre_rating_counted= genre_rating_exp.value_counts().to_frame().sort_index(axis = 0, ascending = True)
genre_rating_counted.head()
# Out:
#            Genre
# Action       150
# Adventure    161
# Animation     68
# Biography     84
# Comedy       168

# %%
#Resetting index
genre_rating_exp = genre_rating_exp.reset_index()
genre_rating_exp
# Out:
#       Rating      Genre
# 0        9.3      Drama
# 1        9.2      Crime
# 2        9.2      Drama
# 3        9.0     Action
# 4        9.0      Crime
# ...      ...        ...
# 1912     7.6    Romance
# 1913     7.6        War
# 1914     7.6  Animation
# 1915     7.6  Adventure
# 1916     7.6     Family
#
# [1917 rows x 2 columns]

# %%
#Grouping data exploded data by Genre to calculate sum of rating for each genre.
grouped_genre_rating =genre_rating_exp.groupby("Genre")["Rating"].sum()

# %%
#converting grouped data in to dataframe
grouped_genre_rating_df = grouped_genre_rating.to_frame()

# %%
grouped_genre_rating_df.head()
# Out:
#            Rating
# Genre
# Action     1193.8
# Adventure  1284.6
# Animation   539.4
# Biography   667.5
# Comedy     1325.2

# %%
#concating total rating and genre count in to single dataframe
genre_rating_final = pd.concat([grouped_genre_rating_df,genre_rating_counted], axis = 1, join = "inner")
genre_rating_final.head()
# Out:
#            Rating  Genre
# Action     1193.8    150
# Adventure  1284.6    161
# Animation   539.4     68
# Biography   667.5     84
# Comedy     1325.2    168

# %%
#Renaming  data frame
genre_rating_final=genre_rating_final.rename(columns={"Rating": "IMDB_Rating", "Genre": "Genre_Count"})

# %%
genre_rating_final = genre_rating_final.rename_axis('Genre')

# %%
genre_rating_final
# Out:
#            IMDB_Rating  Genre_Count
# Genre
# Action          1193.8          150
# Adventure       1284.6          161
# Animation        539.4           68
# Biography        667.5           84
# Comedy          1325.2          168
# Crime           1178.4          148
# Drama           4282.5          538
# Family           300.5           38
# Fantasy          420.7           53
# Film-Noir         80.3           10
# History          292.6           37
# Horror           204.0           26
# Music            229.0           29
# Musical           86.9           11
# Mystery          590.9           74
# Romance          737.8           93
# Sci-Fi           471.0           59
# Sport            111.3           14
# Thriller         815.9          103
# War              307.0           38
# Western          120.9           15

# %%
#calculating average rating for each genre.
genre_rating_final["Averages_By_Genre"] = genre_rating_final["IMDB_Rating"] / genre_rating_final["Genre_Count"]

# %%
genre_rating_final.head()
# Out:
#            IMDB_Rating  Genre_Count  Averages_By_Genre
# Genre
# Action          1193.8          150           7.958667
# Adventure       1284.6          161           7.978882
# Animation        539.4           68           7.932353
# Biography        667.5           84           7.946429
# Comedy          1325.2          168           7.888095

# %%
genre_rating_final = genre_rating_final.reset_index()
genre_rating_final
# Out:
#         Genre  IMDB_Rating  Genre_Count  Averages_By_Genre
# 0      Action       1193.8          150           7.958667
# 1   Adventure       1284.6          161           7.978882
# 2   Animation        539.4           68           7.932353
# 3   Biography        667.5           84           7.946429
# 4      Comedy       1325.2          168           7.888095
# 5       Crime       1178.4          148           7.962162
# 6       Drama       4282.5          538           7.960037
# 7      Family        300.5           38           7.907895
# 8     Fantasy        420.7           53           7.937736
# 9   Film-Noir         80.3           10           8.030000
# 10    History        292.6           37           7.908108
# 11     Horror        204.0           26           7.846154
# 12      Music        229.0           29           7.896552
# 13    Musical         86.9           11           7.900000
# 14    Mystery        590.9           74           7.985135
# 15    Romance        737.8           93           7.933333
# 16     Sci-Fi        471.0           59           7.983051
# 17      Sport        111.3           14           7.950000
# 18   Thriller        815.9          103           7.921359
# 19        War        307.0           38           8.078947
# 20    Western        120.9           15           8.060000

# %%
gen = genre_rating_final["Genre"]
gen_rat = genre_rating_final["Genre_Count"]

plt.figure(figsize = (20,10))
clrs = ['green' if (x < max(gen_rat) and x > min(gen_rat)) else 'red' for x in gen_rat ]
sns.barplot(x = gen, y = gen_rat ,palette=clrs)
plt.title("Frequency of Genre in Top 1000 movies", fontsize = 30,weight = 'bold')
plt.xlabel('Genre', fontsize = 15)
plt.ylabel('Number of times', fontsize = 15 )
plt.xticks(rotation=90 ,fontsize = 12 )
plt.yticks(fontsize = 12 )

plt.show()

# %%
#On average which genre is the most highly rated?
plt.figure(figsize = (20,10))
clrs = ['green' if (x < max(genre_rating_final["Averages_By_Genre"])) else 'red' for x in genre_rating_final["Averages_By_Genre"] ]
sns.barplot(x = genre_rating_final["Genre"],y = genre_rating_final["Averages_By_Genre"] ,palette=clrs)
plt.xlabel('Genre', fontsize = 20)
plt.ylabel("Average Rating", fontsize = 20)
plt.title("Average Rating per Genre", fontsize = 30, weight = 'bold')
plt.xticks(rotation=90, fontsize = 20)
plt.show()
plt.show()

# %%
#On average which genre is the least rated?
plt.figure(figsize = (20,10))
clrs = ['green' if (x > min(genre_rating_final["Averages_By_Genre"])) else 'red' for x in genre_rating_final["Averages_By_Genre"] ]
sns.barplot(x = genre_rating_final["Genre"], y = genre_rating_final["Averages_By_Genre"] ,palette=clrs)
plt.xlabel('Genre', fontsize = 20)
plt.ylabel("Average Rating", fontsize = 20)
plt.title("Average Rating per Genre", fontsize = 30, weight = 'bold')
plt.xticks(rotation=90, fontsize = 20)
plt.show()
plt.show()

# %% [markdown]
# # Genre with highest Gross money

# %%
genre_gross = clean_movies[["Genre","Gross(Million_$)"]]

# %%
genre_gross
# Out:
#                                         Genre  Gross(Million_$)
# 0                           Drama                         28.34
# 1                    Crime, Drama                        134.97
# 2            Action, Crime, Drama                        534.86
# 3        Action, Adventure, Drama                        377.85
# 4       Biography, Drama, History                         96.90
# ..                                        ...               ...
# 989                        Comedy                         44.53
# 990  Animation, Adventure, Comedy                        141.84
# 994                 Drama, Horror                          0.05
# 996           Drama, Romance, War                         30.50
# 997  Animation, Adventure, Family                        184.93
#
# [755 rows x 2 columns]

# %%
genre_gross.set_index("Gross(Million_$)", inplace = True)

# %%
genre_gross.head()
# Out:
#                                                   Genre
# Gross(Million_$)
# 28.34                                 Drama
# 134.97                         Crime, Drama
# 534.86                 Action, Crime, Drama
# 377.85             Action, Adventure, Drama
# 96.90             Biography, Drama, History

# %%
genre1 = genre_gross["Genre"].str.split(", ")
genre_gross_exp = genre1.explode()

# %%
genre_gross_exp = genre_gross_exp.str.strip()
genre_gross_exp.head()
# Out:
# Gross(Million_$)
# 28.34      Drama
# 134.97     Crime
# 134.97     Drama
# 534.86    Action
# 534.86     Crime
# Name: Genre, dtype: object

# %%
genre_gross_value_count = genre_gross_exp.value_counts().to_frame().sort_index(axis = 0, ascending = True)
genre_gross_value_count
# Out:
#            Genre
# Action       150
# Adventure    161
# Animation     68
# Biography     84
# Comedy       168
# Crime        148
# Drama        538
# Family        38
# Fantasy       53
# Film-Noir     10
# History       37
# Horror        26
# Music         29
# Musical       11
# Mystery       74
# Romance       93
# Sci-Fi        59
# Sport         14
# Thriller     103
# War           38
# Western       15

# %%
genre_gross_exp = genre_gross_exp.reset_index()
genre_gross_exp
# Out:
#       Gross(Million_$)      Genre
# 0                28.34      Drama
# 1               134.97      Crime
# 2               134.97      Drama
# 3               534.86     Action
# 4               534.86      Crime
# ...                ...        ...
# 1912             30.50    Romance
# 1913             30.50        War
# 1914            184.93  Animation
# 1915            184.93  Adventure
# 1916            184.93     Family
#
# [1917 rows x 2 columns]

# %%
grouped_genre_gross = genre_gross_exp.groupby("Genre")["Gross(Million_$)"].sum()
grouped_genre_gross = grouped_genre_gross.to_frame()
grouped_genre_gross
# Out:
#            Gross(Million_$)
# Genre
# Action             23212.28
# Adventure          28315.38
# Animation           9048.92
# Biography           5005.17
# Comedy             12941.75
# Crime               7402.78
# Drama              27676.62
# Family              3648.44
# Fantasy             6134.10
# Film-Noir             44.13
# History             2284.67
# Horror              1033.80
# Music               1117.82
# Musical              254.90
# Mystery             3571.91
# Romance             4299.57
# Sci-Fi              9141.71
# Sport                853.52
# Thriller            6185.34
# War                 1361.72
# Western              855.61

# %%
genre_gross_final = pd.concat([grouped_genre_gross,genre_gross_value_count], axis = 1, join = "inner" )
genre_gross_final = genre_gross_final.rename(columns = {"Gross(Million_$)":"Total_Gross(Million_$)", "Genre":"Genre_count"})
genre_gross_final = genre_gross_final.rename_axis("Genre")
genre_gross_final
# Out:
#            Total_Gross(Million_$)  Genre_count
# Genre
# Action                   23212.28          150
# Adventure                28315.38          161
# Animation                 9048.92           68
# Biography                 5005.17           84
# Comedy                   12941.75          168
# Crime                     7402.78          148
# Drama                    27676.62          538
# Family                    3648.44           38
# Fantasy                   6134.10           53
# Film-Noir                   44.13           10
# History                   2284.67           37
# Horror                    1033.80           26
# Music                     1117.82           29
# Musical                    254.90           11
# Mystery                   3571.91           74
# Romance                   4299.57           93
# Sci-Fi                    9141.71           59
# Sport                      853.52           14
# Thriller                  6185.34          103
# War                       1361.72           38
# Western                    855.61           15

# %%
genre_gross_final["Average_by_Genre"]  = round(genre_gross_final["Total_Gross(Million_$)"] / genre_gross_final["Genre_count"],2)
genre_gross_final = genre_gross_final.reset_index()
genre_gross_final
# Out:
#         Genre  Total_Gross(Million_$)  Genre_count  Average_by_Genre
# 0      Action                23212.28          150            154.75
# 1   Adventure                28315.38          161            175.87
# 2   Animation                 9048.92           68            133.07
# 3   Biography                 5005.17           84             59.59
# 4      Comedy                12941.75          168             77.03
# 5       Crime                 7402.78          148             50.02
# 6       Drama                27676.62          538             51.44
# 7      Family                 3648.44           38             96.01
# 8     Fantasy                 6134.10           53            115.74
# 9   Film-Noir                   44.13           10              4.41
# 10    History                 2284.67           37             61.75
# 11     Horror                 1033.80           26             39.76
# 12      Music                 1117.82           29             38.55
# 13    Musical                  254.90           11             23.17
# 14    Mystery                 3571.91           74             48.27
# 15    Romance                 4299.57           93             46.23
# 16     Sci-Fi                 9141.71           59            154.94
# 17      Sport                  853.52           14             60.97
# 18   Thriller                 6185.34          103             60.05
# 19        War                 1361.72           38             35.83
# 20    Western                  855.61           15             57.04

# %%
#On average which movie genre makes the most gross money and which genre makes the least?
plt.figure(figsize = (20,10))
clrs = ['green' if (x < max(genre_gross_final["Average_by_Genre"])) else 'red' for x in genre_gross_final["Average_by_Genre"] ]
sns.barplot(x = genre_gross_final["Genre"], y = genre_gross_final["Average_by_Genre"] ,palette = clrs)
plt.xlabel('Genre', fontsize = 20)
plt.ylabel("Average Gross (Million_$)", fontsize = 20)
plt.title("Average Gross per Genre", fontsize = 30, weight = 'bold')
plt.xticks(rotation=90, fontsize = 20)
plt.show()
plt.show()

# %%
#On average which movie genre makes the most gross money and which genre makes the least?
plt.figure(figsize = (20,10))
clrs = ['green' if (x > min(genre_gross_final["Average_by_Genre"])) else 'red' for x in genre_gross_final["Average_by_Genre"] ]
sns.barplot(x = genre_gross_final["Genre"], y = genre_gross_final["Average_by_Genre"] ,palette = clrs)
plt.xlabel('Genre', fontsize = 20)
plt.ylabel("Average Gross (Million_$)", fontsize = 20)
plt.title("Average Gross per Genre", fontsize = 30, weight = 'bold')
plt.xticks(rotation=90, fontsize = 20)
plt.show()
plt.show()

# %% [markdown]
# # Genre with highest Metascore

# %%
genre_meta = clean_movies[["Genre", "Metascore"]]

# %%
genre_meta.head()
# Out:
#                                    Genre  Metascore
# 0                      Drama                   81.0
# 1               Crime, Drama                  100.0
# 2       Action, Crime, Drama                   84.0
# 3   Action, Adventure, Drama                   94.0
# 4  Biography, Drama, History                   94.0

# %%
genre_meta.set_index("Metascore", inplace = True)
genre_meta
# Out:
#                                               Genre
# Metascore
# 81.0                              Drama
# 100.0                      Crime, Drama
# 84.0               Action, Crime, Drama
# 94.0           Action, Adventure, Drama
# 94.0          Biography, Drama, History
# ...                                             ...
# 86.0                             Comedy
# 65.0       Animation, Adventure, Comedy
# 90.0                      Drama, Horror
# 85.0                Drama, Romance, War
# 95.0       Animation, Adventure, Family
#
# [755 rows x 1 columns]

# %%
genre2 = genre_meta["Genre"].str.split(", ")
genre_meta_exp = genre2.explode()
genre_meta_exp = genre_meta_exp.str.strip()
genre_meta_exp
# Out:
# Metascore
# 81.0         Drama
# 100.0        Crime
# 100.0        Drama
# 84.0        Action
# 84.0         Crime
#            ...
# 85.0       Romance
# 85.0           War
# 95.0     Animation
# 95.0     Adventure
# 95.0        Family
# Name: Genre, Length: 1917, dtype: object

# %%
genre_meta_value_count = genre_meta_exp.value_counts().to_frame().sort_index(axis = 0, ascending = True)

# %%
genre_meta_value_count
# Out:
#            Genre
# Action       150
# Adventure    161
# Animation     68
# Biography     84
# Comedy       168
# Crime        148
# Drama        538
# Family        38
# Fantasy       53
# Film-Noir     10
# History       37
# Horror        26
# Music         29
# Musical       11
# Mystery       74
# Romance       93
# Sci-Fi        59
# Sport         14
# Thriller     103
# War           38
# Western       15

# %%
genre_meta_exp = genre_meta_exp.reset_index()
genre_meta_exp
# Out:
#       Metascore      Genre
# 0          81.0      Drama
# 1         100.0      Crime
# 2         100.0      Drama
# 3          84.0     Action
# 4          84.0      Crime
# ...         ...        ...
# 1912       85.0    Romance
# 1913       85.0        War
# 1914       95.0  Animation
# 1915       95.0  Adventure
# 1916       95.0     Family
#
# [1917 rows x 2 columns]

# %%
genre_meta_grouped = genre_meta_exp.groupby("Genre")["Metascore"].sum().to_frame()
genre_meta_grouped
# Out:
#            Metascore
# Genre
# Action       11233.0
# Adventure    12612.0
# Animation     5521.0
# Biography     6499.0
# Comedy       13106.0
# Crime        11257.0
# Drama        42221.0
# Family        2967.0
# Fantasy       4030.0
# Film-Noir      919.0
# History       2883.0
# Horror        2007.0
# Music         2254.0
# Musical        832.0
# Mystery       5864.0
# Romance       7539.0
# Sci-Fi        4506.0
# Sport         1053.0
# Thriller      7911.0
# War           3097.0
# Western       1220.0

# %%
genre_meta_final = pd.concat([genre_meta_grouped, genre_meta_value_count],axis = 1, join = "inner")
genre_meta_final.reset_index(inplace = True)
genre_meta_final= genre_meta_final.rename(columns={"index":"Genre","Metascore":"Sum_of_metascore","Genre":"Genre_count"})
genre_meta_final
# Out:
#         Genre  Sum_of_metascore  Genre_count
# 0      Action           11233.0          150
# 1   Adventure           12612.0          161
# 2   Animation            5521.0           68
# 3   Biography            6499.0           84
# 4      Comedy           13106.0          168
# 5       Crime           11257.0          148
# 6       Drama           42221.0          538
# 7      Family            2967.0           38
# 8     Fantasy            4030.0           53
# 9   Film-Noir             919.0           10
# 10    History            2883.0           37
# 11     Horror            2007.0           26
# 12      Music            2254.0           29
# 13    Musical             832.0           11
# 14    Mystery            5864.0           74
# 15    Romance            7539.0           93
# 16     Sci-Fi            4506.0           59
# 17      Sport            1053.0           14
# 18   Thriller            7911.0          103
# 19        War            3097.0           38
# 20    Western            1220.0           15

# %%
genre_meta_final["Average_by_genre"] = genre_meta_final["Sum_of_metascore"] / genre_meta_final["Genre_count"]
genre_meta_final
# Out:
#         Genre  Sum_of_metascore  Genre_count  Average_by_genre
# 0      Action           11233.0          150         74.886667
# 1   Adventure           12612.0          161         78.335404
# 2   Animation            5521.0           68         81.191176
# 3   Biography            6499.0           84         77.369048
# 4      Comedy           13106.0          168         78.011905
# 5       Crime           11257.0          148         76.060811
# 6       Drama           42221.0          538         78.477695
# 7      Family            2967.0           38         78.078947
# 8     Fantasy            4030.0           53         76.037736
# 9   Film-Noir             919.0           10         91.900000
# 10    History            2883.0           37         77.918919
# 11     Horror            2007.0           26         77.192308
# 12      Music            2254.0           29         77.724138
# 13    Musical             832.0           11         75.636364
# 14    Mystery            5864.0           74         79.243243
# 15    Romance            7539.0           93         81.064516
# 16     Sci-Fi            4506.0           59         76.372881
# 17      Sport            1053.0           14         75.214286
# 18   Thriller            7911.0          103         76.805825
# 19        War            3097.0           38         81.500000
# 20    Western            1220.0           15         81.333333

# %%
#On average which genre has the highest Average Metascore and which genre has the least?

gen1 =  genre_meta_final["Genre_count"]
meta_avg = genre_meta_final["Average_by_genre"]

plt.figure(figsize = (20,10))
clrs = ['green' if (x < max(meta_avg) and x > min(meta_avg)) else 'red' for x in meta_avg ]
sns.barplot(x = gen, y = meta_avg ,palette = clrs)
plt.xlabel('Genre', fontsize = 15)
plt.ylabel("Average Metascore", fontsize = 15)
plt.title("Average Metascore per Genre", fontsize = 30, weight = 'bold')
plt.xticks(rotation=90, fontsize = 12)
plt.yticks(fontsize = 12)

plt.show()
